# %%
from dputils.scrape import Scraper, Tag

# %%
def get_data(query, page=1):
    scraper = Scraper(f'https://www.amazon.in/s?k={query}&page={page}')
    print(scraper.soup.title)
    target= Tag(cls='s-main-slot s-result-list s-search-results sg-row')
    items= Tag(cls='s-result-item')
    brand = Tag('h5')
    title = Tag('h2')
    price = Tag('span',cls='a-price-whole')
    rating = Tag('span', cls='a-size-base')
    oprice = Tag('span', cls='a-offscreen')
    return scraper.get_all(target, items,
        brand=brand, title=title, price=price, 
        rating=rating, oprice=oprice)

# %%
query = 'watch'

all_data = []
for i in range(1,11):
    print(f'fetching page {i} data')
    data = get_data(query, i)
    if len(data) == 0:
        print('No more data')
        break
    all_data.extend(data)
all_data
# Out:
# fetching page 1 data
# <title>Amazon.in : watch</title>
# fetching page 2 data
# <title>Amazon.in : watch</title>
# fetching page 3 data
# <title>Amazon.in : watch</title>
# fetching page 4 data
# <title>Amazon.in : watch</title>
# fetching page 5 data
# <title>Amazon.in : watch</title>
# fetching page 6 data
# <title>Amazon.in : watch</title>
# fetching page 7 data
# <title>Amazon.in : watch</title>
# fetching page 8 data
# <title>Amazon.in : watch</title>
# fetching page 9 data
# <title>Amazon.in : watch</title>
# fetching page 10 data
# <title>Amazon.in : watch</title>
# [{'brand': None,
#   'title': None,
#   'price': '1,999.',
#   'rating': None,
#   'oprice': '₹1,999.00'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9138-SB NF9138 Analog-Digital Watch - for Men  ',
#   'price': '2,352',
#   'rating': '4.0',
#   'oprice': '₹2,352'},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9190-SILVER NF9190 Analog-Digital Watch - for Men  ',
#   'price': '2,552',
#   'rating': '2.7',
#   'oprice': '₹2,552'},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9172-SILVER NF9172 Analog-Digital Watch - for Men  ',
#   'price': '2,252',
#   'rating': '4.5',
#   'oprice': '₹2,252'},
#  {'brand': 'NAVIFORCE',
#   'title': 'Dual time Wrist Watch for Men  ',
#   'price': '2,552',
#   'rating': '5.0',
#   'oprice': '₹2,552'},
#  {'brand': 'USM',
#   'title': 'USM ID116 Smart Watch Smart Bracelet Fitness Tracker Color Screen Smartwatch Heart Rate Blood Pressure Pedometer Sleep Monitor  ',
#   'price': '329',
#   'rating': '4.5',
#   'oprice': '₹329'},
#  {'brand': 'boAt',
#   'title': 'boAt Flash Edition Smart Watch with Activity Tracker, Multiple Sports Modes, 1.3" Screen, 170+ Watch Faces, Sleep Monitor, Gesture, Camera & Music Control, IP68 & 7 Days Battery Life(Lightning Black)  ',
#   'price': '1,499',
#   'rating': '4.0',
#   'oprice': '₹1,499'},
#  {'brand': 'boAt',
#   'title': 'boAt Wave Prime47 Smart Watch with 1.69" HD Display, 700+ Active Modes, ASAP Charge, Live Cricket Scores, Crest App Health Ecosystem, HR & SpO2 Monitoring(Forest Green)  ',
#   'price': '1,199',
#   'rating': '3.3',
#   'oprice': '₹1,199'},
#  {'brand': 'MARCLEX',
#   'title': "Affordable Men's Watch, Men's LED Digital Watch, Watch for Boys & Gents Watches Combo Pack of 2  ",
#   'price': '249',
#   'rating': '5.0',
#   'oprice': '₹249'},
#  {'brand': 'MARCLEX',
#   'title': "Affordable Men's Watch, Men's LED Digital Watch, Watch for Boys & Gents Watches Combo Pack of 2  ",
#   'price': '249',
#   'rating': '5.0',
#   'oprice': '₹249'},
#  {'brand': 'Renaissance Traders',
#   'title': "Analogue Women's Watch (White Dial Rose Gold Colored Strap)  ",
#   'price': '249',
#   'rating': '4.0',
#   'oprice': '₹249'},
#  {'brand': 'IIK COLLECTION',
#   'title': 'Watches for Women Round Studded Dial |Analogue Quartz Movemnet Ladies Watch|Long Battery Life|Stainless Steel Adjustable Bracelet Chain Strap|Double Lock Clasp Safety Watches for Girls  ',
#   'price': '349',
#   'rating': '4.8',
#   'oprice': '₹349'},
#  {'brand': 'CLOUDWOOD',
#   'title': 'Digital Vintage Square Dial Unisex Wrist Watch for Men & Women -W70  ',
#   'price': '299',
#   'rating': '4.0',
#   'oprice': '₹299'},
#  {'brand': 'VILLS LAURRENS',
#   'title': '0024 Gold Dial Metallic Chain Analog Watch for Men and Boys  ',
#   'price': '389',
#   'rating': '5.0',
#   'oprice': '₹389'},
#  {'brand': 'CLOUDWOOD',
#   'title': 'Digital Vintage Square Dial Unisex Wrist Watch for Men & Women -W70  ',
#   'price': '299',
#   'rating': '4.0',
#   'oprice': '₹299'},
#  {'brand': 'SWISSTYLE',
#   'title': 'Black Dial Blue Strap Analog Watch - for Men-SS-GR6622-BLU-BLU  ',
#   'price': '149',
#   'rating': '5.0',
#   'oprice': '₹149'},
#  {'brand': 'MF MINI FOCUS',
#   'title': "Women's Watch - RK-MF0335L-P  ",
#   'price': '6,779',
#   'rating': '5.0',
#   'oprice': '₹6,779'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Noise',
#   'title': 'Noise ColorFit Pulse Grand Smart Watch with 1.69"(42.9cm) HD Display, 60 Sports Modes, 150 Watch Faces, Fast Charge, Spo2, Stress, Sleep, Heart Rate Monitoring & IP68 Waterproof (Champagne Grey)  ',
#   'price': '1,299',
#   'rating': '4.0',
#   'oprice': '₹1,299'},
#  {'brand': 'boAt',
#   'title': 'boAt Wave Prime47 Smart Watch with 1.69" HD Display, 700+ Active Modes, ASAP Charge, Live Cricket Scores, Crest App Health Ecosystem, HR & SpO2 Monitoring(Matte Black)  ',
#   'price': '1,199',
#   'rating': '3.3',
#   'oprice': '₹1,199'},
#  {'brand': 'Tokdis',
#   'title': 'Tokdis MX-1 Pro Bluetooth Calling Smartwatch - 1.69” LCD Display, Multiple Watch Faces, Sleep Monitor, Heart & SpO2 Monitoring, Multiple Sports Modes  ',
#   'price': '799',
#   'rating': '3.1',
#   'oprice': '₹799'},
#  {'brand': 'Generic',
#   'title': 'SHREENOVA® ID116 Plus Bluetooth Fitness Smart Watch for Men Women and Kids Activity Tracker (Black)  ',
#   'price': '385',
#   'rating': '3.2',
#   'oprice': '₹385'},
#  {'brand': 'Hammer',
#   'title': 'Hammer Ace 3.0 Bluetooth Calling Smart Watch with Largest 1.85" IPS Display, Dual Mode, Spo2, Heart Rate, Strong Metallic Body & Skin Friendly Strap (Black)  ',
#   'price': '1,499',
#   'rating': '4.5',
#   'oprice': '₹1,499'},
#  {'brand': 'LOUIS DEVIN',
#   'title': 'Silicone Strap Analog Wrist Watch for Men (Black/Blue/Red) | LD-BK054  ',
#   'price': '399',
#   'rating': '4.0',
#   'oprice': '₹399'},
#  {'brand': 'Shocknshop',
#   'title': 'Digital Sports Multi Functional Black Dial Watch for Mens Boys -315RED  ',
#   'price': '284',
#   'rating': '3.8',
#   'oprice': '₹284'},
#  {'brand': 'TIMEX',
#   'title': "Analog Men's Watch  ",
#   'price': '849',
#   'rating': 'Shop coveted styles with many reviews',
#   'oprice': '₹849'},
#  {'brand': 'TIMEX',
#   'title': "Analog Men's Watch  ",
#   'price': '849',
#   'rating': '4.1',
#   'oprice': '₹849'},
#  {'brand': 'Fastrack',
#   'title': "Analog Dial Women's Watch (Pink, 6150SM04)-NM6150SM04 / NL6150SM04/NP6150SM04  ",
#   'price': '1,750',
#   'rating': '4.4',
#   'oprice': '₹1,750'},
#  {'brand': 'SWISSTONE',
#   'title': "Analog Women's Watch (Pink Dial Silver Colored Strap)  ",
#   'price': '326',
#   'rating': '4.1',
#   'oprice': '₹326'},
#  {'brand': 'SF',
#   'title': "Sporty Analog Black Dial Men's Watch-NL7930PP01/NP7930PP01  ",
#   'price': '625',
#   'rating': '4.0',
#   'oprice': '₹625'},
#  {'brand': 'TIMEX',
#   'title': "Analog Women's Watch (Dial Colored Strap)  ",
#   'price': '2,032',
#   'rating': '4.4',
#   'oprice': '₹2,032'},
#  {'brand': 'Casio',
#   'title': 'Youth Series Digital Black Dial Unisex Watch - F-91W-1Q(D002)  ',
#   'price': '1,095',
#   'rating': '4.4',
#   'oprice': '₹1,095'},
#  {'brand': 'SF',
#   'title': "Venus Digital Grey Dial Men's Watch-NL7982PP04/NM7982PP04  ",
#   'price': '499',
#   'rating': '4.1',
#   'oprice': '₹499'},
#  {'brand': 'Fastrack',
#   'title': "Casual Analog White Dial Men's Watch NM3114PP01/NN3114PP01/NP3114PP01  ",
#   'price': '1,095',
#   'rating': '4.1',
#   'oprice': '₹1,095'},
#  {'brand': 'Premium Wrist Watches for Men',
#   'title': "Chronograph Men's Watch (Black Dial)  ",
#   'price': '17,495',
#   'rating': 'Written by',
#   'oprice': '₹17,495'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Bouncefit',
#   'title': 'Bouncefit Fitness Band Smart Watch- Y68 D20 Water Proof Smart Watches SpO2 Full Touch Smartwatch with Workout Modes, Heart Rate Tracking, Sports Smart Watch for All Boys & Girls & Women - Jet Black  ',
#   'price': '480',
#   'rating': '3.3',
#   'oprice': '₹480'},
#  {'brand': 'TIMEWEAR',
#   'title': 'Analog Day Date Functioning Stainless Steel Chain Watch for Men  ',
#   'price': '319',
#   'rating': '3.8',
#   'oprice': '₹319'},
#  {'brand': 'ADAMO',
#   'title': "Digital 24 Images Projector Watch for Kids Boys Watch, Diwali Gift, Birthday Return Gift, Best Digital Toy Watch for Boy's & Girl's BG-906  ",
#   'price': '289',
#   'rating': '4.0',
#   'oprice': '₹289'},
#  {'brand': 'boAt',
#   'title': 'boAt Flash Edition Smart Watch with Activity Tracker, Multiple Sports Modes, 1.3" Screen, 170+ Watch Faces, Sleep Monitor, Gesture, Camera & Music Control, IP68 & 7 Days Battery Life(Galaxy Blue)  ',
#   'price': '1,199',
#   'rating': '4.0',
#   'oprice': '₹1,199'},
#  {'brand': 'OnePlus',
#   'title': 'OnePlus Nord Watch with 1.78” AMOLED Display, 60 Hz Refresh Rate, 105 Fitness Modes, 10 Days Battery, SPO2, Heart Rate, Stress Monitor, Women Health Tracker & Multiple Watch Faces [Deep Blue]  ',
#   'price': '4,999',
#   'rating': '3.9',
#   'oprice': '₹4,999'},
#  {'brand': 'Fire-Boltt',
#   'title': 'Fire-Boltt Gladiator 1.96" Biggest Display Smart Watch with Bluetooth Calling, Voice Assistant &123 Sports Modes, 8 Unique UI Interactions, SpO2, 24/7 Heart Rate Tracking, Rs 100 Off on UPI  ',
#   'price': '2,499',
#   'rating': '4.0',
#   'oprice': '₹2,499'},
#  {'brand': 'SHASHIKIRAN',
#   'title': "Boy's Glowing Light Digital Watch with Music on Theme of Spiderman and Ironman (Multicolor, Combo of 2)  ",
#   'price': '649',
#   'rating': '4.0',
#   'oprice': '₹649'},
#  {'brand': 'Fossil',
#   'title': "Chronograph White Dial Men's Watch-CH2882  ",
#   'price': '4,935',
#   'rating': '4.3',
#   'oprice': '₹4,935'},
#  {'brand': 'just like',
#   'title': 'Set of 3 Leathers Strap Multi Color Wrist Analog Watch for Boy and Men  ',
#   'price': '429',
#   'rating': 'New to Amazon',
#   'oprice': '₹429'},
#  {'brand': 'Maicrogear',
#   'title': "Luxury Chronograph Watch for Men's  ",
#   'price': '2,999',
#   'rating': 'New to Amazon',
#   'oprice': '₹2,999'},
#  {'brand': 'LOCREST',
#   'title': 'Smart Watch for men women boys 1.3" OLED HD Display, Multiple watch Faces, SpO2 Monitoring, Sleep Monitor for Boys, Girls, Mens, Women & Kids for all Smartphones (ID 116 Plus Black) (ID116 Black)  ',
#   'price': '419',
#   'rating': '4.6',
#   'oprice': '₹419'},
#  {'brand': 'Fire-Boltt',
#   'title': 'Fire-Boltt Gladiator 1.96" Biggest Display Smart Watch with Bluetooth Calling, Voice Assistant &123 Sports Modes, 8 Unique UI Interactions, SpO2, 24/7 Heart Rate Tracking, Rs 100 Off on UPI  ',
#   'price': '2,499',
#   'rating': '4.0',
#   'oprice': '₹2,499'},
#  {'brand': 'VMBS',
#   'title': 'VMBS A1 Smart Watch Mobile Inbuild Camera Supporting 4G/5G Sim Smartwatch for Phone  ',
#   'price': '990',
#   'rating': '2.1',
#   'oprice': '₹990'},
#  {'brand': 'Mobivax',
#   'title': 'Smart Watch for Men Women ID116 Plus Smart Bracelet Fitness Tracker Color Screen Smartwatch Heart Rate Blood Pressure Pedometer Sleep Monitor  ',
#   'price': '399',
#   'rating': '4.5',
#   'oprice': '₹399'},
#  {'brand': 'Matrix',
#   'title': 'Analog Day & Date Display Wrist Watch for Men & Boys (Black)  ',
#   'price': '299',
#   'rating': '3.6',
#   'oprice': '₹299'},
#  {'brand': 'Drawya',
#   'title': 'Smart Watch D20 Y68 Smart Watch for Girls Boys Men Women Kids, Blacktooth 1.3" Smart Watch LED with Daily Activity Tracker, Heart Rate Sensor, for All Boys & Girls SmartWatch- Pink  ',
#   'price': '499',
#   'rating': '2.0',
#   'oprice': '₹499'},
#  {'brand': 'Shocknshop',
#   'title': "Stainless Steel Watch Series Analogue Men's Watch (Black Dial Mens Long Colored Strap) -W219  ",
#   'price': '285',
#   'rating': '3.8',
#   'oprice': '₹285'},
#  {'brand': 'Shocknshop',
#   'title': 'Simple Sport Digital Men’s Military Watches Electronic LED Time Black Wrist Watch  ',
#   'price': '449',
#   'rating': '3.8',
#   'oprice': '₹449'},
#  {'brand': 'REDUX',
#   'title': "Analog Boy's & Men's Watch (Blue Dial Blue Colored Strap)  ",
#   'price': '266',
#   'rating': '3.6',
#   'oprice': '₹266'},
#  {'brand': 'hamt',
#   'title': "Analog Men's Watch (Multicolor Dial Multi Colored Strap)  ",
#   'price': '129',
#   'rating': '3.2',
#   'oprice': '₹129'},
#  {'brand': 'VILLS LAURRENS',
#   'title': '9951 Pure Black Chain Day & Date Wrist Watch Original Black Watch Analog Watch - for Men  ',
#   'price': '399',
#   'rating': '3.0',
#   'oprice': '₹399'},
#  {'brand': 'Fastrack',
#   'title': 'Analog Grey Dial Unisex-Adult Watch-68011PP08  ',
#   'price': '895',
#   'rating': '4.2',
#   'oprice': '₹895'},
#  {'brand': 'Tommy Hilfiger',
#   'title': "Analog Blue Dial Men's Watch-TH1791474  ",
#   'price': '11,500',
#   'rating': '4.5',
#   'oprice': '₹11,500'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Analogue Multi Color Dial Kids Watch for Boys and Girls - Combo of 2 Watches  ',
#   'price': '249',
#   'rating': '3.5',
#   'oprice': '₹249'},
#  {'brand': 'SELLORIA',
#   'title': 'Digital Watch Shockproof Multi-Functional Automatic Black Color Strap Waterproof Digital Sports Watch for Mens Kids Watch for Boys Watch for Men Pack of 1 Watch Water Resistance Digital Watch  ',
#   'price': '199',
#   'rating': '3.8',
#   'oprice': '₹199'},
#  {'brand': 'V2A',
#   'title': "Analogue - Digital Men's Watch (Black Dial Black Colored Strap)  ",
#   'price': '799',
#   'rating': '3.8',
#   'oprice': '₹799'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Multi Dial Chronograph Luxury Quartz Analog Watch for Men  ',
#   'price': '339',
#   'rating': '3.8',
#   'oprice': '₹339'},
#  {'brand': 'Generic',
#   'title': 'SHREENOVA XA Smart Watch for Men & Women Latest Bluetooth 1.3" LED with Daily Activity Tracker, Heart Rate Sensor,Sports Gym Watch for All Boys & Girls - Black  ',
#   'price': '295',
#   'rating': '3.0',
#   'oprice': '₹295'},
#  {'brand': 'Sylvi',
#   'title': "Premium Casual Stylish Watch | Luxury Working Chronograph Watch for Men | Water-Resistant Branded Men's Wrist Watch with Stopwatch & Date Display - Timegrapher Red Leather Watch  ",
#   'price': '1,109',
#   'rating': '3.3',
#   'oprice': '₹1,109'},
#  {'brand': 'boAt',
#   'title': 'boAt Matrix Smart Watch with 1.65” AMOLED Display, Always On Mode, Slim Premium Design, Heart Rate & SpO2 Monitoring, Health Ecosystem & Multiple Sports Modes, 3ATM & 7 Days Battery Life(Pitch Black)  ',
#   'price': '1,499',
#   'rating': '3.9',
#   'oprice': '₹1,499'},
#  {'brand': 'SWISSTYLE',
#   'title': "Analogue Black Dial Men's Watch - SS-GR918-BLK-BLK  ",
#   'price': '149',
#   'rating': '2.5',
#   'oprice': '₹149'},
#  {'brand': 'Generic',
#   'title': 'New Edition i7 Pro Max All in One Series 7 Smart Watch with Fitness Tracker Heart Monitor Men Women Smart Watch Black  ',
#   'price': '599',
#   'rating': '3.3',
#   'oprice': '₹599'},
#  {'brand': 'SWISSTONE',
#   'title': "Analog Men's Watch (Brown Dial Brown Colored Strap)  ",
#   'price': '299',
#   'rating': '3.6',
#   'oprice': '₹299'},
#  {'brand': 'DIZO',
#   'title': 'DIZO Watch D2 Power (by realme TechLife) –Large 1.91" Superlight, Single Chipset Bluetooth Calling Smartwatch with Smart Swipe,150 +Stylish Watch Faces and 10 Day Battery (Classic Black)  ',
#   'price': '1,799',
#   'rating': '3.7',
#   'oprice': '₹1,799'},
#  {'brand': 'Acnos',
#   'title': 'Black Dial Analogue Watch for Men Pack of 1 (FULLBLKPAYDU)  ',
#   'price': '265',
#   'rating': '3.5',
#   'oprice': '₹265'},
#  {'brand': 'MAGBOT',
#   'title': 'MAGBOT Q9 Smart Watch for Men & Women Latest Bluetooth 1.3" LED with Daily Activity Tracker, Heart Rate Sensor, BP Monitor, Sports Gym Watch for All Boys & Girls - Black  ',
#   'price': '499',
#   'rating': '3.7',
#   'oprice': '₹499'},
#  {'brand': 'boAt',
#   'title': 'boAt Xtend Smart Watch with Alexa Built-in, 1.69” HD Display, Multiple Watch Faces, Stress Monitor, HR & SpO2 Monitoring, 14 Sports Modes, Sleep Monitor, 5 ATM & 7 Days Battery Life(Deep Blue)  ',
#   'price': '1,799',
#   'rating': '4.2',
#   'oprice': '₹1,799'},
#  {'brand': 'CURREN',
#   'title': "Analog Men's Watch ( Dial Blue Colored Strap)  ",
#   'price': '2,695',
#   'rating': '4.1',
#   'oprice': '₹2,695'},
#  {'brand': 'VYL',
#   'title': 'Smart watch New Launch Smart Watches ID116 Bluetooth Smartwatch Wireless Fitness Band for Boys, Girls, Men, Women & Kids | Sports Gym Watch for All Smart Phones I Heart Rate and spo2 Monitor - (Black)  ',
#   'price': '499',
#   'rating': '2.7',
#   'oprice': '₹499'},
#  {'brand': 'Noise',
#   'title': 'Noise ColorFit Pulse Grand Smart Watch with 1.69"(4.2cm) HD Display, 60 Sports Modes, 150 Watch Faces, Fast Charge, Spo2, Stress, Sleep, Heart Rate Monitoring & IP68 Waterproof (Lime Green)  ',
#   'price': '1,499',
#   'rating': '4.0',
#   'oprice': '₹1,499'},
#  {'brand': 'FANMIS',
#   'title': 'Unisex Elegant Plane Style Digital Display Waterproof Outdoor Sports Silicone Strap LED Wrist Watch ( black )  ',
#   'price': '390',
#   'rating': '3.4',
#   'oprice': '₹390'},
#  {'brand': 'Apple',
#   'title': 'Apple Watch Series 8 [GPS 45 mm] Smart Watch w/Midnight Aluminium Case with Midnight Sport Band. Fitness Tracker, Blood Oxygen & ECG Apps, Always-On Retina Display, Water Resistant  ',
#   'price': '45,400',
#   'rating': '4.6',
#   'oprice': '₹45,400'},
#  {'brand': 'Fossil',
#   'title': "Chronograph Men's Watch (Black Dial Black Colored Strap)  ",
#   'price': '6,597',
#   'rating': '4.1',
#   'oprice': '₹6,597'},
#  {'brand': 'VILLS LAURRENS',
#   'title': '0024 Gold Dial Metallic Chain Analog Watch for Men and Boys  ',
#   'price': '389',
#   'rating': '5.0',
#   'oprice': '₹389'},
#  {'brand': 'Fossil',
#   'title': "Grant Chronograph Black Dial Men's Watch-FS4832  ",
#   'price': '8,115',
#   'rating': '4.2',
#   'oprice': '₹8,115'},
#  {'brand': 'Sylvi',
#   'title': "Vogue Style Brown Leather Strap Analog Digital Men's Sports Wrist Watch  ",
#   'price': '990',
#   'rating': '3.9',
#   'oprice': '₹990'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': '\n                                                    watch for boys\n                                                ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': '1,999.',
#   'rating': None,
#   'oprice': '₹1,999.00'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': 'Price and other details may vary based on product size and colour.',
#   'oprice': None},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9138-SB NF9138 Analog-Digital Watch - for Men  ',
#   'price': '2,352',
#   'rating': '4.0',
#   'oprice': '₹2,352'},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9190-SILVER NF9190 Analog-Digital Watch - for Men  ',
#   'price': '2,552',
#   'rating': '2.7',
#   'oprice': '₹2,552'},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9172-SILVER NF9172 Analog-Digital Watch - for Men  ',
#   'price': '2,252',
#   'rating': '4.5',
#   'oprice': '₹2,252'},
#  {'brand': 'NAVIFORCE',
#   'title': 'Dual time Wrist Watch for Men  ',
#   'price': '2,552',
#   'rating': '5.0',
#   'oprice': '₹2,552'},
#  {'brand': 'NIBOSI',
#   'title': "Men's Watches Luxury Fashion Casual Dress Chronograph Waterproof Military Quartz Wristwatches for Men Stainless Steel Band  ",
#   'price': '2,290',
#   'rating': '3.8',
#   'oprice': '₹2,290'},
#  {'brand': 'VYL',
#   'title': 'Smart watch New Launch Smart Watches ID116 Bluetooth Smartwatch Wireless Fitness Band for Boys, Girls, Men, Women & Kids | Sports Gym Watch for All Smart Phones I Heart Rate and spo2 Monitor - (Black)  ',
#   'price': '499',
#   'rating': '2.7',
#   'oprice': '₹499'},
#  {'brand': 'V2A',
#   'title': "Analog-Digital Men's Watch (Black Dial Black Colored Strap)  ",
#   'price': '990',
#   'rating': '4.1',
#   'oprice': '₹990'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'pTron',
#   'title': 'pTron Force X12S Bluetooth Calling Smartwatch, 1.85" Full Touch HD Display, Functional Crown, Real Heart Rate Monitor, SpO2, Watch Faces, 5 Days Battery Life, Fitness Trackers & IP68 Waterproof (Pink)  ',
#   'price': '1,549',
#   'rating': '3.3',
#   'oprice': '₹1,549'},
#  {'brand': 'CURREN',
#   'title': "Analog Men's Watch ( Dial Blue Colored Strap)  ",
#   'price': '2,695',
#   'rating': '4.1',
#   'oprice': '₹2,695'},
#  {'brand': 'Apple',
#   'title': 'Apple Watch SE (2nd Gen) [GPS 44 mm] Smart Watch w/Midnight Aluminium Case & Midnight Sport Band. Fitness & Sleep Tracker, Crash Detection, Heart Rate Monitor, Retina Display, Water Resistant  ',
#   'price': '31,900',
#   'rating': '4.6',
#   'oprice': '₹31,900'},
#  {'brand': 'The Shopoholic',
#   'title': 'Analog Dial Black Metal Strap Watch Series Watches for Men Watch for Man and Watch for Boys  ',
#   'price': '284',
#   'rating': '3.5',
#   'oprice': '₹284'},
#  {'brand': 'boAt',
#   'title': 'boAt Wave Lite Smartwatch with 1.69 Inches(4.29cm) HD Display, Heart Rate & SpO2 Level Monitor, Multiple Watch Faces, Activity Tracker, Multiple Sports Modes & IP68 (Scarlet Red)  ',
#   'price': '1,499',
#   'rating': '3.9',
#   'oprice': '₹1,499'},
#  {'brand': 'FANMIS',
#   'title': 'Unisex Elegant Plane Style Digital Display Waterproof Outdoor Sports Silicone Strap LED Wrist Watch ( black )  ',
#   'price': '390',
#   'rating': '3.4',
#   'oprice': '₹390'},
#  {'brand': 'DIZO',
#   'title': 'DIZO Watch D2 Power (by realme TechLife) – Large 1.91" Superlight, Single Chipset Bluetooth Calling Smartwatch with Smart Swipe, 150+Stylish Watch Faces and 10 Day Battery (Steel Grey)  ',
#   'price': '1,799',
#   'rating': '3.7',
#   'oprice': '₹1,799'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Generic',
#   'title': 'LED Digital Watch Good Looking Black Watch for Boys & Girls (Black Color)  ',
#   'price': '95',
#   'rating': '2.8',
#   'oprice': '₹95'},
#  {'brand': 'AYL',
#   'title': 'AYL Smart Watch New Generation for You ID116 Touchscreen Android Smart Watch Bluetooth Smartwatch with Heart Rate Sensor and Basic Functionality for All Women, Men, Boys & Girls - Black  ',
#   'price': '499',
#   'rating': '3.4',
#   'oprice': '₹499'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Square Multi DIAL Analog Silicon Strap ADDI Stylish Designer Analog Watch - for Boys  ',
#   'price': '189',
#   'rating': '3.5',
#   'oprice': '₹189'},
#  {'brand': 'Fastrack',
#   'title': 'New Fastrack Reflex Beat+ 1.69” UltraVU Display|500 Nits Brightness|60 Sports Modes|24*7 Heart Rate Monitor|SpO2 Monitor|Sleep Tracker|IP68 Water Resistant|Music & Camera Control  ',
#   'price': '1,695',
#   'rating': '4.0',
#   'oprice': '₹1,695'},
#  {'brand': 'BENYAR',
#   'title': 'Wrist Watches for Men Leather Strap Analog Chronograph Fashion Business Sport Design Mens Watch 30M Waterproof Stylish Elegant Gifts for Men  ',
#   'price': '2,890',
#   'rating': '4.1',
#   'oprice': '₹2,890'},
#  {'brand': None,
#   'title': 'Maxima Max Pro X4+ Rugged Bluetooth Calling Smart Watch 1.32" Round Always on Premium Display with 360x360 px Resolution, AI Voice Assitant, Advance UI, 340 mah Big Battery, HR/SpO2, 150+ Watch Faces  ',
#   'price': '2,400',
#   'rating': '3.7',
#   'oprice': '₹2,400'},
#  {'brand': 'NAVIFORCE',
#   'title': '9190  ',
#   'price': '2,552',
#   'rating': '5.0',
#   'oprice': '₹2,552'},
#  {'brand': 'NAVIFORCE',
#   'title': "Men's Business Casual Date And Day Display Quartz Clock Military Sports Stainless Steel Waterproof Analogue Wristwatch  ",
#   'price': '2,152',
#   'rating': '4.2',
#   'oprice': '₹2,152'},
#  {'brand': 'NAVIFORCE',
#   'title': "Men's Business Casual Date And Day Display Quartz Clock Military Sports Stainless Steel Waterproof Analogue Wristwatch ( Black )  ",
#   'price': '2,152',
#   'rating': '4.2',
#   'oprice': '₹2,152'},
#  {'brand': 'NAVIFORCE',
#   'title': "NAVIFORCE Men's Analog Chronograph Quartz Watch with Stainless Steel Bracelet NF9165  ",
#   'price': '2,952',
#   'rating': '4.3',
#   'oprice': '₹2,952'},
#  {'brand': 'OLEVS',
#   'title': "Chronograph Analogue Men's Luxury Watch (Blue Dial)  ",
#   'price': '2,890',
#   'rating': '3.9',
#   'oprice': '₹2,890'},
#  {'brand': 'CrossBeats',
#   'title': 'CrossBeats Ignite S5 Advanced AI ENC BT Calling Smartwatch, 1.96” Super AMOLED Anti-Glare Screen, Always on Display, Calculator, 500+ Watch Faces, 360 Degree Health Tracking, Fast Charge (Silver)  ',
#   'price': '4,499',
#   'rating': '4.1',
#   'oprice': '₹4,499'},
#  {'brand': 'REDUX',
#   'title': "Analog Boy's & Men's Watch (Brown Dial Colored Strap)  ",
#   'price': '265',
#   'rating': '3.4',
#   'oprice': '₹265'},
#  {'brand': 'Hammer',
#   'title': 'Hammer Pulse Ace Pro Bluetooth Calling Smartwatch with SpO2 & 1.81” Aluminium Alloy Body with Blood Oxygen Monitoring, Heart Rate, Full Touch & Multiple Watch Faces with Customization (Black)  ',
#   'price': '1,798',
#   'rating': '3.8',
#   'oprice': '₹1,798'},
#  {'brand': 'Casio',
#   'title': "Formal Analog White Dial Men's Watch-MTP-V300L-7AUDF (A1177)  ",
#   'price': '3,795',
#   'rating': '4.2',
#   'oprice': '₹3,795'},
#  {'brand': 'CERO',
#   'title': "Digital Dial Men's & Women's Watch(AB206-VSD)  ",
#   'price': '299',
#   'rating': '2.5',
#   'oprice': '₹299'},
#  {'brand': 'AYL',
#   'title': 'AYL Waterproof D-20 Touch Screen Smart Watch Bluetooth Smartwatch with Blood Pressure Tracking, Heart Rate Sensor and Basic Functionality for All Women and Girls (Pink)  ',
#   'price': '470',
#   'rating': '3.3',
#   'oprice': '₹470'},
#  {'brand': 'LS LAPSTER Quality Assured',
#   'title': 'Lapster USB all types smartwatch charger cable for boat watch charger & boat xtend watch charger & boat storm watch charger- All 2 Pin Watch (Cable Only)  ',
#   'price': '113',
#   'rating': '3.4',
#   'oprice': '₹113'},
#  {'brand': 'Sonata',
#   'title': 'Analog Watches for Men  ',
#   'price': '899',
#   'rating': '4.3',
#   'oprice': '₹899'},
#  {'brand': 'Sonata',
#   'title': "Analog Champagne Dial Women's Watch-NL87018YM01/NP87018YM01  ",
#   'price': '825',
#   'rating': '4.2',
#   'oprice': '₹825'},
#  {'brand': 'RUSTET',
#   'title': 'Silicone Strap Analog Wrist Watch for Men (Black/Blue/Red) | LD-BK054  ',
#   'price': '349',
#   'rating': '3.9',
#   'oprice': '₹349'},
#  {'brand': 'OLICOM',
#   'title': 'OLICOM M1 Smart Watch Id-116 Bluetooth Smartwatch Wireless Fitness Band for Boys, Girls, Men, Women & Kids | Sports Gym Watch for All Smart Phones I Heart Rate and spo2 Monitor  ',
#   'price': '499',
#   'rating': '3.6',
#   'oprice': '₹499'},
#  {'brand': 'Fastrack',
#   'title': 'Fastrack Reflex Hello Smart Watch with BT Calling|Bright HD Display|AI Voice Assistant|50+ Sports Modes|100+ Watchfaces|BP Monitor|24x7 HRM| SpO2|Upto 5 Day Battery|Camera & Music Control|IP68  ',
#   'price': '3,995',
#   'rating': '3.8',
#   'oprice': '₹3,995'},
#  {'brand': 'FORSINING',
#   'title': "Analogue Men's Watch(Gold Dial Silver Colored Strap)-S1089-2  ",
#   'price': '4,099',
#   'rating': '4.0',
#   'oprice': '₹4,099'},
#  {'brand': 'Fire-Boltt',
#   'title': 'Fire-Boltt Ninja 3 1.83" Display Smartwatch Full Touch with 100+ Sports Modes with IP68, Sp02 Tracking, Over 100 Cloud Based Watch Faces  ',
#   'price': '1,299',
#   'rating': '4.2',
#   'oprice': '₹1,299'},
#  {'brand': 'Sonata',
#   'title': "Play Analog Rose Gold Dial Women's Watch-NN8141WM01/NP8141WM01  ",
#   'price': '1,949',
#   'rating': '4.1',
#   'oprice': '₹1,949'},
#  {'brand': 'Fastrack',
#   'title': "Analog Black Dial Men's Watch-NG38022PP03W / NG38022PP03C  ",
#   'price': '795',
#   'rating': '4.4',
#   'oprice': '₹795'},
#  {'brand': 'SKMEI',
#   'title': "Men's Digital Sports Watch, LED Square Large Face Analog Quartz Wrist Watch with Multi-Time Zone Waterproof Stopwatch - 1834/1835  ",
#   'price': '839',
#   'rating': '3.9',
#   'oprice': '₹839'},
#  {'brand': 'BITZAG',
#   'title': 'New LED Watch for Boys, Girls and Kids Digital Black Dial Led Watch for Kids Unisex Birthday Gift Digital Watch  ',
#   'price': '100',
#   'rating': '3.9',
#   'oprice': '₹100'},
#  {'brand': 'HEMT',
#   'title': 'Gold Dial Day n Date Display Analog Wrist Watch HM-GR095-GLD-SLV  ',
#   'price': '429',
#   'rating': '3.7',
#   'oprice': '₹429'},
#  {'brand': 'Sonata',
#   'title': "Super Fibre Digital Grey Dial Men's Watch-NL87011PP04/NP87011PP04  ",
#   'price': '600',
#   'rating': '4.2',
#   'oprice': '₹600'},
#  {'brand': 'HEMT',
#   'title': "Analog Blue Dial Men's Watch-HM-GR092-BLU-C  ",
#   'price': '259',
#   'rating': '3.7',
#   'oprice': '₹259'},
#  {'brand': 'ADAMO',
#   'title': "Digital 24 Images Projector Watch for Kids Boys Watch, Diwali Gift, Birthday Return Gift, Best Digital Toy Watch for Boy's & Girl's BG-906  ",
#   'price': '289',
#   'rating': '4.0',
#   'oprice': '₹289'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Avenger Black Dial Watch for Men & Boys  ',
#   'price': '189',
#   'rating': '3.4',
#   'oprice': '₹189'},
#  {'brand': 'pTron',
#   'title': 'PTron Newly Launched Force X10 Bluetooth Calling Smartwatch with 1.7" Full Touch Color Display, Real Heart Rate Monitor, SpO2, Watch Faces, 5 Days Runtime, Fitness Trackers & IP68 Waterproof (Pink)  ',
#   'price': '1,499',
#   'rating': '3.2',
#   'oprice': '₹1,499'},
#  {'brand': 'Barbie',
#   'title': 'Barbie Digital Unisex Child Watch (Pink Dial Pink Colored Strap)  ',
#   'price': '297',
#   'rating': '3.3',
#   'oprice': '₹297'},
#  {'brand': 'Titan',
#   'title': 'Talk S with 1.78" AMOLED Display|Advanced BT Calling|Music Storage with Wireless Audio Connect|100+ Sports Modes|Animated Watchfaces|5 Days Battery|IP68 Water Resistant|Stress & Mood Monitor  ',
#   'price': '12,995',
#   'rating': '4.1',
#   'oprice': '₹12,995'},
#  {'brand': 'APCSA',
#   'title': 'APCSA Original New Series 7 D20 Bluetooth Wireless Smart Watch, Fitness Band for Boys, Girls, Men, Women & Kids | Sports Watch for All Smart Phones I Heart Rate and BP Monitor ( Pink )  ',
#   'price': '499',
#   'rating': '3.3',
#   'oprice': '₹499'},
#  {'brand': 'FROZIL',
#   'title': "Digital Watch Shockproof Multi-Functional Automatic Full Black Color Strap Waterproof Digital Sports Watch for Men's Kids Watch for Boys Watch for Men Pack of-1  ",
#   'price': '280',
#   'rating': '3.7',
#   'oprice': '₹280'},
#  {'brand': 'TIMEX',
#   'title': 'A500  ',
#   'price': '712',
#   'rating': '4.0',
#   'oprice': '₹712'},
#  {'brand': 'Acnos',
#   'title': 'Special Super Quality Analog Watches Combo Look Like Handsome for Boys and Mens Pack of - 3(STL-437-436)  ',
#   'price': '535',
#   'rating': '3.6',
#   'oprice': '₹535'},
#  {'brand': 'Lionmati',
#   'title': 'Watch for Boys and Girl Spider Men Kids Light Glowing Watch with Music Tune and Face Cover Multicolor Led Digital Light Kid Watch {3-9 Year Red  ',
#   'price': None,
#   'rating': '3.8',
#   'oprice': None},
#  {'brand': 'GUESS',
#   'title': 'Mens Trend Champagne Watch - GW0516G2  ',
#   'price': '17,496.',
#   'rating': 'New to Amazon',
#   'oprice': '₹17,496.50'},
#  {'brand': 'Generic',
#   'title': 'Digital Multi Function Kids Sports Watch for Boys & Girls  ',
#   'price': '239',
#   'rating': 'New to Amazon',
#   'oprice': '₹239'},
#  {'brand': 'NAVIFORCE',
#   'title': "Analogue-Digital Men's Watch (Black Dial)  ",
#   'price': '2,252',
#   'rating': '4.0',
#   'oprice': '₹2,252'},
#  {'brand': 'Maicrogear',
#   'title': "Luxury Chronograph Watch for Men's  ",
#   'price': '2,999',
#   'rating': 'New to Amazon',
#   'oprice': '₹2,999'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': '\n                                                    watch for boys\n                                                ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': '1,999.',
#   'rating': None,
#   'oprice': '₹1,999.00'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'casera',
#   'title': 'Mahadev Dial And Mahadev Bracelet And Watch Combo Set For Boy And Men  ',
#   'price': '259',
#   'rating': '3.9',
#   'oprice': '₹259'},
#  {'brand': 'Sylvi',
#   'title': "Vogue Style Brown Leather Strap Analog Digital Men's Sports Wrist Watch  ",
#   'price': '990',
#   'rating': '3.9',
#   'oprice': '₹990'},
#  {'brand': 'Maicrogear',
#   'title': "Luxury Chronograph Watch for Men's  ",
#   'price': '2,999',
#   'rating': 'New to Amazon',
#   'oprice': '₹2,999'},
#  {'brand': 'Fossil',
#   'title': "Chronograph Men's Watch (Black Dial Black Colored Strap)  ",
#   'price': '6,597',
#   'rating': '4.1',
#   'oprice': '₹6,597'},
#  {'brand': 'Fire-Boltt',
#   'title': 'Fire-Boltt Ninja Fit Smartwatch Full Touch 1.69 & 120+ Sports Modes with IP68, Multi UI Screen, Over 100 Cloud Based Watch Faces, Built in Games  ',
#   'price': '1,299',
#   'rating': '4.2',
#   'oprice': '₹1,299'},
#  {'brand': 'Fossil',
#   'title': "Dean Chronograph Black Dial Men's Watch-FS4721  ",
#   'price': '8,636',
#   'rating': '4.2',
#   'oprice': '₹8,636'},
#  {'brand': 'Fire-Boltt',
#   'title': 'Fire-Boltt Gladiator 1.96" Biggest Display Smart Watch with Bluetooth Calling, Voice Assistant &123 Sports Modes, 8 Unique UI Interactions, SpO2, 24/7 Heart Rate Tracking, Rs 100 Off on UPI  ',
#   'price': '2,499',
#   'rating': '4.0',
#   'oprice': '₹2,499'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Acnos',
#   'title': "Luxury Analogue Girl's Watch(Multicolour Dial 1-Multicolour Colored Strap)  ",
#   'price': '385',
#   'rating': '3.9',
#   'oprice': '₹385'},
#  {'brand': 'MARVIK',
#   'title': 'MARVIK Smart Watch D116 for Xiaomi Mi Note 9 Smart Watch Bluetooth SmartWatch with Activity Tracker, Heart Rate Sensor, Sleep Monitor and Basic Functionality for All Boys & Girls  ',
#   'price': '494',
#   'rating': '3.1',
#   'oprice': '₹494'},
#  {'brand': 'TIMEX',
#   'title': "Classics Analog Beige Dial Women's Watch -B301  ",
#   'price': '599',
#   'rating': '4.2',
#   'oprice': '₹599'},
#  {'brand': 'Sonata',
#   'title': "Analog White Dial Men's Watch-7135SL03/NP7135SL03  ",
#   'price': '875',
#   'rating': '4.2',
#   'oprice': '₹875'},
#  {'brand': 'ZUPERIA',
#   'title': "Digital Boy's & Men's Watch (Multicolour Dial Multi Colored Strap)  ",
#   'price': '231',
#   'rating': '3.8',
#   'oprice': '₹231'},
#  {'brand': 'Redmi',
#   'title': 'Redmi Watch 2 Lite - Multi-System Standalone GPS, 3.94 cm Large HD Edge Display, Continuous SpO2, Stress & Sleep Monitoring, 24x7 HR, 5ATM, 120+ Watch Faces, 100+ Sports Modes, Women’s Health, Black  ',
#   'price': '2,400',
#   'rating': '3.9',
#   'oprice': '₹2,400'},
#  {'brand': 'IIK COLLECTION',
#   'title': 'Watches for Women Stainless Steel Chain & Diamond Studded Dial Ladies Watch - Water Resistant Womens Watches  ',
#   'price': '399',
#   'rating': '4.2',
#   'oprice': '₹399'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'CrossBeats',
#   'title': 'CrossBeats Ignite S5 Advanced AI ENC BT Calling Smartwatch, 1.96” Super AMOLED Anti-Glare Screen, Always on Display, Calculator, 500+ Watch Faces, 360 Degree Health Tracking, Fast Charge (Silver)  ',
#   'price': '4,499',
#   'rating': '4.1',
#   'oprice': '₹4,499'},
#  {'brand': 'Sonata',
#   'title': "Digital Grey Dial Men's Watch-NL77072PP02/NP77072PP02  ",
#   'price': '599',
#   'rating': '4.3',
#   'oprice': '₹599'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Analogue Watch for Men and Boys  ',
#   'price': '219',
#   'rating': '3.7',
#   'oprice': '₹219'},
#  {'brand': 'CYLECT',
#   'title': 'CYLECT Smart Watch for Men women - Smart Watches for Men Women, Bluetooth Smartwatch Touch Screen Bluetooth Smart Watches for Android iOS Phones Wrist Phone Watch, Women - pink  ',
#   'price': '598',
#   'rating': '3.8',
#   'oprice': '₹598'},
#  {'brand': 'Casio',
#   'title': "Formal Analog White Dial Men's Watch-MTP-V300L-7AUDF (A1177)  ",
#   'price': '3,795',
#   'rating': '4.2',
#   'oprice': '₹3,795'},
#  {'brand': 'Titan',
#   'title': "Neo Analog White Dial Men's Watch-NN1805SL04  ",
#   'price': '5,795',
#   'rating': '4.6',
#   'oprice': '₹5,795'},
#  {'brand': 'Fossil',
#   'title': "Chronograph White Dial Men's Watch-CH2882  ",
#   'price': '4,935',
#   'rating': '4.3',
#   'oprice': '₹4,935'},
#  {'brand': 'REDUX',
#   'title': "Analog Boy's & Men's Watch (Blue Dial Blue Colored Strap)  ",
#   'price': '266',
#   'rating': '3.6',
#   'oprice': '₹266'},
#  {'brand': 'VILLS LAURRENS',
#   'title': '0024 Gold Dial Metallic Chain Analog Watch for Men and Boys  ',
#   'price': '389',
#   'rating': '5.0',
#   'oprice': '₹389'},
#  {'brand': 'EVOTECH',
#   'title': 'EVOTECH Black Pink Fashion Digital Date and Time Black Dial LED Watch/Stylish Boys & Girls-Kids Birthday Gift/Cartoon Character Avengers Super Hero (Doll)  ',
#   'price': '299',
#   'rating': '5.0',
#   'oprice': '₹299'},
#  {'brand': 'Fastrack',
#   'title': 'Fastrack Reflex Hello Smart Watch with BT Calling|Bright HD Display|AI Voice Assistant|50+ Sports Modes|100+ Watchfaces|BP Monitor|24x7 HRM| SpO2|Upto 5 Day Battery|Camera & Music Control|IP68  ',
#   'price': '3,995',
#   'rating': '3.8',
#   'oprice': '₹3,995'},
#  {'brand': 'Sonata',
#   'title': 'Analog Watches for Men  ',
#   'price': '955',
#   'rating': '4.3',
#   'oprice': '₹955'},
#  {'brand': 'TIMEX',
#   'title': 'A500  ',
#   'price': '712',
#   'rating': '4.0',
#   'oprice': '₹712'},
#  {'brand': 'ZUPERIA',
#   'title': 'Diamond Studded Stylish Analogue Watch with Rose Gold Dot Bracelet for Girls & Women  ',
#   'price': '240',
#   'rating': '3.8',
#   'oprice': '₹240'},
#  {'brand': 'SKMEI',
#   'title': "Men's Digital Sports Wrist Watch LED Screen Large Face Electronics Military Watches Waterproof Alarm Stopwatch Back Light Outdoor Casual Black Watch  ",
#   'price': None,
#   'rating': '3.9',
#   'oprice': None},
#  {'brand': 'Maxima',
#   'title': 'Newly Launched Maxima Max Pro Knight Bluetooth Calling smartwatch with 44.5mm Round Active Display of 550 Nits Brightness, Voice Assistant, HR & SpO2 Monitor,30+ Excercise Modes, inbuilt Games  ',
#   'price': '2,499',
#   'rating': '3.5',
#   'oprice': '₹2,499'},
#  {'brand': 'Fastrack',
#   'title': 'Analog Grey Dial Unisex-Adult Watch-68013PP10  ',
#   'price': '950',
#   'rating': '4.2',
#   'oprice': '₹950'},
#  {'brand': 'CrossBeats',
#   'title': 'CrossBeats Newly launched Ignite S5 Advanced AI ENC BT Calling Smartwatch, 1.96” Super AMOLED Anti-Glare Screen, Always on Display, SnapCharge™ Calculator, 500+ Watch Faces, AI Health Feature (Black)  ',
#   'price': '4,499',
#   'rating': '4.1',
#   'oprice': '₹4,499'},
#  {'brand': 'DIZO',
#   'title': 'DIZO Watch D2 Power (by realme TechLife) – Large 1.91" Superlight, Single Chipset Bluetooth Calling Smartwatch with Smart Swipe, 150+Stylish Watch Faces and 10 Day Battery (Steel Grey)  ',
#   'price': '1,799',
#   'rating': '3.7',
#   'oprice': '₹1,799'},
#  {'brand': 'CERO',
#   'title': "Boy's Avenger Printed Analog Watch and King Bracelet Combo (Black)  ",
#   'price': '249',
#   'rating': '3.7',
#   'oprice': '₹249'},
#  {'brand': 'ZEBRONICS',
#   'title': 'Zebronics DRIP Smart Watch with Bluetooth Calling, 4.3cm (1.69"), 10 built-in & 100+ Watch Faces, 100+ Sport Modes, 4 built-in Games, Voice Assistant, 8 Menu UI, Fitness Health & Sleep Tracker (Black)  ',
#   'price': '1,799',
#   'rating': '3.8',
#   'oprice': '₹1,799'},
#  {'brand': 'Fastrack',
#   'title': "Analog Black Dial Men's Watch-NG38022PP03W / NG38022PP03C  ",
#   'price': '795',
#   'rating': '4.4',
#   'oprice': '₹795'},
#  {'brand': 'Sonata',
#   'title': "Analog Silver Dial Men's Watch-7142NL01  ",
#   'price': '1,099',
#   'rating': '3.3',
#   'oprice': '₹1,099'},
#  {'brand': 'Fastrack',
#   'title': "Fundamentals Analog Grey Dial Women's Watch-NL68010SM04/NP68010SM04  ",
#   'price': '1,550',
#   'rating': '4.3',
#   'oprice': '₹1,550'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Artistic Love Symbol Butterfly Red Analog Watch for Girls and Women Watch - for Girls  ',
#   'price': '189',
#   'rating': '3.3',
#   'oprice': '₹189'},
#  {'brand': 'SENS',
#   'title': 'SENS NUTON 1 with 1.7 IPS Display, Orbiter, 5ATM & 150+ Watch Faces & Free Additional Strap (Royal Silver)  ',
#   'price': '1,099',
#   'rating': '3.9',
#   'oprice': '₹1,099'},
#  {'brand': 'Fastrack',
#   'title': "Casual Analog Black Dial Men's Watch-3254NM01  ",
#   'price': '2,195',
#   'rating': '3.4',
#   'oprice': '₹2,195'},
#  {'brand': None,
#   'title': 'Maxima Max Pro X4+ Rugged Bluetooth Calling Smart Watch 1.32" Round Always on Premium Display with 360x360 px Resolution, AI Voice Assitant, Advance UI, 340 mah Big Battery, HR/SpO2, 150+ Watch Faces  ',
#   'price': '2,400',
#   'rating': '3.7',
#   'oprice': '₹2,400'},
#  {'brand': 'Talgo',
#   'title': 'Analogue Minimalist Round Black Dial Latest Generation Stainless Steel Linked Chain Black Strap Stylish Wrist Watch for Men and Boys, Pack of 1 - IIKBKMEN  ',
#   'price': '372',
#   'rating': '3.6',
#   'oprice': '₹372'},
#  {'brand': 'Samsung',
#   'title': 'Samsung Galaxy Watch4 Classic Bluetooth(4.2 cm, Black, Compatible with Android Only)  ',
#   'price': '18,000',
#   'rating': '4.3',
#   'oprice': '₹18,000'},
#  {'brand': 'NAVIFORCE',
#   'title': "Analog-Digital Men's Watch (Black Dial)  ",
#   'price': '2,351',
#   'rating': '4.1',
#   'oprice': '₹2,351'},
#  {'brand': 'Armani Exchange',
#   'title': "Chronograph Men's Watch (Black Dial)  ",
#   'price': '12,995',
#   'rating': '4.3',
#   'oprice': '₹12,995'},
#  {'brand': 'Noise',
#   'title': 'Noise ColorFit Pro 4 Max 1.8" Biggest Display, Bluetooth Calling Smart Watch, Built.in Alexa, 100 Sports Modes, Detection, Health & Productivity Suite (Jet Black)  ',
#   'price': '3,999',
#   'rating': '4.0',
#   'oprice': '₹3,999'},
#  {'brand': 'Titan',
#   'title': "Analog OffWhite Dial Men's Watch NM1712YM02 / NL1712YM02  ",
#   'price': '1,995',
#   'rating': '4.3',
#   'oprice': '₹1,995'},
#  {'brand': 'DANIEL KLEIN',
#   'title': "Analog Brown Dial Women's Watch-DK11467-6  ",
#   'price': '2,780',
#   'rating': '4.0',
#   'oprice': '₹2,780'},
#  {'brand': 'Fire-Boltt',
#   'title': 'Fire-Boltt Eterno 1.99" Largest Display, Bluetooth Calling Smartwatch with 1184mm Display Area, AI Voice Assistant, 120+ Sports Modes (Yoga) with Smart Split Screen to Toggle between functions, Gaming on the Wrist  ',
#   'price': '2,499',
#   'rating': '4.3',
#   'oprice': '₹2,499'},
#  {'brand': 'MARVIK',
#   'title': 'MARVIK Smart Watch D116 for Xiaomi Mi Note 10 Smart Watch LED with Activity Tracker, Heart Rate Sensor, Sleep Monitor and Basic Functionality for All Boys Girls  ',
#   'price': '449',
#   'rating': '3.1',
#   'oprice': '₹449'},
#  {'brand': 'Generic',
#   'title': 'Zaha New Generation Digital Square Watch for Boys & Girls & Kids (Pink)  ',
#   'price': '110',
#   'rating': '1.5',
#   'oprice': '₹110'},
#  {'brand': 'Sonata',
#   'title': "Super Fibre Digital Grey Dial Men's Watch-NL87011PP04/NP87011PP04  ",
#   'price': '600',
#   'rating': '4.2',
#   'oprice': '₹600'},
#  {'brand': 'Fire-Boltt',
#   'title': 'Fire-Boltt Ring Bluetooth Calling Smartwatch with SpO2 & 1.7” Metal Body with Blood Oxygen Monitoring, Continuous Heart Rate, Full Touch & Multiple Watch Faces (Blue)  ',
#   'price': '2,299',
#   'rating': '4.1',
#   'oprice': '₹2,299'},
#  {'brand': 'RORIOS',
#   'title': "Fashion Men's Watches Analog Quartz Watch Cool Creative Wristwatch with Stainless Steel Mesh Brecelet Sport Watch for Men  ",
#   'price': '10,079',
#   'rating': '4.1',
#   'oprice': '₹10,079'},
#  {'brand': 'Sonata',
#   'title': "Analog Champagne Dial Women's Watch-NL87018YM01/NP87018YM01  ",
#   'price': '825',
#   'rating': '4.2',
#   'oprice': '₹825'},
#  {'brand': 'just like',
#   'title': 'Set of 3 Leathers Strap Multi Color Wrist Analog Watch for Boy and Men  ',
#   'price': '429',
#   'rating': 'New to Amazon',
#   'oprice': '₹429'},
#  {'brand': 'VILLS LAURRENS',
#   'title': 'HMT-DLX BLK Quartz Original Gold Plated Day & Date Functioning Watch for Boys Analog Watch - for Men  ',
#   'price': '349',
#   'rating': '3.2',
#   'oprice': '₹349'},
#  {'brand': 'VILLS LAURRENS',
#   'title': "VL-1187 SLV Silver Dial Day & Date Series Analog Men's Watch  ",
#   'price': '359',
#   'rating': '5.0',
#   'oprice': '₹359'},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9138-SB NF9138 Analog-Digital Watch - for Men  ',
#   'price': '2,352',
#   'rating': '4.0',
#   'oprice': '₹2,352'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': '\n                                                    watch for boys\n                                                ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': '1,999.',
#   'rating': None,
#   'oprice': '₹1,999.00'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Sylvi',
#   'title': "Vogue Style Brown Leather Strap Analog Digital Men's Sports Wrist Watch  ",
#   'price': '990',
#   'rating': '3.9',
#   'oprice': '₹990'},
#  {'brand': 'SHASHIKIRAN',
#   'title': "Boy's Glowing Light Digital Watch with Music on Theme of Spiderman and Ironman (Multicolor, Combo of 2)  ",
#   'price': '649',
#   'rating': '4.0',
#   'oprice': '₹649'},
#  {'brand': 'Fossil',
#   'title': "Chronograph Men's Watch (Black Dial Black Colored Strap)  ",
#   'price': '6,597',
#   'rating': '4.1',
#   'oprice': '₹6,597'},
#  {'brand': 'Maicrogear',
#   'title': "Luxury Chronograph Watch for Men's  ",
#   'price': '2,999',
#   'rating': 'M.R.P: ',
#   'oprice': '₹2,999'},
#  {'brand': 'Sonata',
#   'title': "Analog White Dial Men's Watch-7135SL03/NP7135SL03  ",
#   'price': '875',
#   'rating': '4.2',
#   'oprice': '₹875'},
#  {'brand': 'Apple',
#   'title': 'Apple Watch Series 8 [GPS 41 mm] Smart Watch w/Midnight Aluminium Case with Midnight Sport Band. Fitness Tracker, Blood Oxygen & ECG Apps, Always-On Retina Display, Water Resistant  ',
#   'price': '41,900',
#   'rating': '4.6',
#   'oprice': '₹41,900'},
#  {'brand': 'Titan',
#   'title': "Neo Analog White Dial Men's Watch-NN1805SL04  ",
#   'price': '5,795',
#   'rating': '4.6',
#   'oprice': '₹5,795'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Casio',
#   'title': "Edifice Chronograph Black Dial Men's Watch - EFR-526L-1AVUDF (EX096)  ",
#   'price': '6,495',
#   'rating': '4.3',
#   'oprice': '₹6,495'},
#  {'brand': 'Keith Buckley',
#   'title': 'Watch: A Novel  ',
#   'price': '939.',
#   'rating': '4.6',
#   'oprice': '₹939.86'},
#  {'brand': 'sunway',
#   'title': "sunway M3 Silicone LED Digital Black Men's Women's Watch  ",
#   'price': '100',
#   'rating': '2.8',
#   'oprice': '₹100'},
#  {'brand': 'Sonata',
#   'title': "Analog Champagne Dial Women's Watch-NL87018YL01/NP87018YL01W  ",
#   'price': '625',
#   'rating': '4.2',
#   'oprice': '₹625'},
#  {'brand': 'Acnos',
#   'title': 'Black Round Diamond Dial with Latest Generation Purple & Rosegold Magnet Belt Analogue Watch for Women Pack of - 2 (DM-PURPLE-ROSEGOLD05)  ',
#   'price': '345',
#   'rating': '3.8',
#   'oprice': '₹345'},
#  {'brand': 'Fastrack',
#   'title': 'Analog Grey Dial Unisex-Adult Watch-68013PP10  ',
#   'price': '950',
#   'rating': '4.2',
#   'oprice': '₹950'},
#  {'brand': 'Apple',
#   'title': 'Apple Watch Ultra [GPS + Cellular 49 mm] Smart Watch w/Rugged Titanium Case & White Ocean Band. Fitness Tracker, Precision GPS, Action Button, Extra-Long BatteryLife, Brighter Retina Display  ',
#   'price': '89,899',
#   'rating': '4.2',
#   'oprice': '₹89,899'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'MARVIK',
#   'title': 'MARVIK Smart Watch D116 for Xiaomi Mi Note 10 Smart Watch LED with Activity Tracker, Heart Rate Sensor, Sleep Monitor and Basic Functionality for All Boys Girls  ',
#   'price': '449',
#   'rating': '3.1',
#   'oprice': '₹449'},
#  {'brand': 'CERO',
#   'title': "Boy's Avenger Printed Analog Watch and King Bracelet Combo (Black)  ",
#   'price': '249',
#   'rating': '3.7',
#   'oprice': '₹249'},
#  {'brand': 'Fire-Boltt',
#   'title': 'Fire-Boltt Ring Bluetooth Calling Smartwatch with SpO2 & 1.7” Metal Body with Blood Oxygen Monitoring, Continuous Heart Rate, Full Touch & Multiple Watch Faces (Blue)  ',
#   'price': '2,299',
#   'rating': '4.1',
#   'oprice': '₹2,299'},
#  {'brand': 'Fire-Boltt',
#   'title': 'Fire-Boltt Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240 * 280 Pixel High Resolution  ',
#   'price': '1,799',
#   'rating': '4.3',
#   'oprice': '₹1,799'},
#  {'brand': 'Fastrack',
#   'title': "Casual Analog Black Dial Men's Watch-3254NM01  ",
#   'price': '2,195',
#   'rating': '3.4',
#   'oprice': '₹2,195'},
#  {'brand': 'Titan',
#   'title': "Analog Blue Dial Women's Watch-NL2574SM01/NP2574SM01  ",
#   'price': '1,795',
#   'rating': '4.3',
#   'oprice': '₹1,795'},
#  {'brand': 'Fossil',
#   'title': "Chronograph White Dial Men's Watch-CH2882  ",
#   'price': '4,935',
#   'rating': '4.3',
#   'oprice': '₹4,935'},
#  {'brand': 'REDUX',
#   'title': "Analog Boy's & Men's Watch (Blue Dial Blue Colored Strap)  ",
#   'price': '266',
#   'rating': '3.6',
#   'oprice': '₹266'},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9190-SILVER NF9190 Analog-Digital Watch - for Men  ',
#   'price': '2,552',
#   'rating': '2.7',
#   'oprice': '₹2,552'},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9138-SB NF9138 Analog-Digital Watch - for Men  ',
#   'price': '2,352',
#   'rating': '4.0',
#   'oprice': '₹2,352'},
#  {'brand': 'Sonata',
#   'title': "Analog Silver Dial Men's Watch-7142NL01  ",
#   'price': '1,099',
#   'rating': '3.3',
#   'oprice': '₹1,099'},
# ...
#   'price': '1,647',
#   'rating': '4.4',
#   'oprice': '₹1,647'},
#  {'brand': 'French Connection',
#   'title': "Analog Dial Women's Watch  ",
#   'price': '2,415.',
#   'rating': '4.3',
#   'oprice': '₹2,415.49'},
#  {'brand': 'Fastrack',
#   'title': "Analog-Digital Black Dial Men's Watch-NL38035SL03/NP38035SL03  ",
#   'price': '4,495',
#   'rating': '4.2',
#   'oprice': '₹4,495'},
#  {'brand': 'Shocknshop',
#   'title': 'Analogue Unisex Couple Combo Watch for Men & Women (Brown Dial & Colored Strap) -W246-236BR  ',
#   'price': '419',
#   'rating': '3.8',
#   'oprice': '₹419'},
#  {'brand': 'APCSA',
#   'title': 'APCSA Smart Watch for Men & Women Latest Bluetooth 1.3" LED with Daily Activity Tracker, Heart Rate Sensor, BP Monitor, Sports Gym Watch for All Boys & Girls - Pink  ',
#   'price': '599',
#   'rating': '3.4',
#   'oprice': '₹599'},
#  {'brand': 'Joker & Witch',
#   'title': 'Phile Black Dial NATO Watch  ',
#   'price': '786',
#   'rating': '3.7',
#   'oprice': '₹786'},
#  {'brand': 'Sonata',
#   'title': "Analog White Dial Men's Watch NM7987YM05W/NN7987YM05W/NP7987YM05W  ",
#   'price': '999',
#   'rating': '4.2',
#   'oprice': '₹999'},
#  {'brand': 'SF',
#   'title': "Economy Digital Multi-color Round Dial Men's Sport Watch-NN77006PP01/NP77006PP01  ",
#   'price': '748',
#   'rating': '3.9',
#   'oprice': '₹748'},
#  {'brand': 'VILLS LAURRENS',
#   'title': '0024 Gold Dial Metallic Chain Analog Watch for Men and Boys  ',
#   'price': '389',
#   'rating': '5.0',
#   'oprice': '₹389'},
#  {'brand': 'VILLS LAURRENS',
#   'title': "VL-1187 SLV Silver Dial Day & Date Series Analog Men's Watch  ",
#   'price': '359',
#   'rating': '5.0',
#   'oprice': '₹359'},
#  {'brand': 'Maicrogear',
#   'title': "Luxury Chronograph Watch for Men's  ",
#   'price': '2,999',
#   'rating': 'M.R.P: ',
#   'oprice': '₹2,999'},
#  {'brand': 'VILLS LAURRENS',
#   'title': 'HMT-DLX BLK Quartz Original Gold Plated Day & Date Functioning Watch for Boys Analog Watch - for Men  ',
#   'price': '349',
#   'rating': '3.2',
#   'oprice': '₹349'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': '\n                                                    watch for boys\n                                                ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': '1,999.',
#   'rating': None,
#   'oprice': '₹1,999.00'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Sylvi',
#   'title': "Vogue Style Brown Leather Strap Analog Digital Men's Sports Wrist Watch  ",
#   'price': '990',
#   'rating': '3.9',
#   'oprice': '₹990'},
#  {'brand': 'casera',
#   'title': 'Mahadev Dial And Mahadev Bracelet And Watch Combo Set For Boy And Men  ',
#   'price': '259',
#   'rating': '3.9',
#   'oprice': '₹259'},
#  {'brand': 'Fossil',
#   'title': "Chronograph White Dial Men's Watch-CH2882  ",
#   'price': '4,935',
#   'rating': '4.3',
#   'oprice': '₹4,935'},
#  {'brand': 'Fossil',
#   'title': "Chronograph Men's Watch (Black Dial Black Colored Strap)  ",
#   'price': '6,597',
#   'rating': '4.1',
#   'oprice': '₹6,597'},
#  {'brand': 'Fastrack',
#   'title': 'New Fastrack Reflex Beat+ 1.69” UltraVU Display|500 Nits Brightness|60 Sports Modes|24*7 Heart Rate Monitor|SpO2 Monitor|Sleep Tracker|IP68 Water Resistant|Music & Camera Control  ',
#   'price': '1,695',
#   'rating': '4.0',
#   'oprice': '₹1,695'},
#  {'brand': 'TIMEX',
#   'title': "Analog Women's Watch (Dial Colored Strap)  ",
#   'price': '2,149',
#   'rating': '4.4',
#   'oprice': '₹2,149'},
#  {'brand': 'Titan',
#   'title': "Analog Dial Women's Watch  ",
#   'price': '1,970',
#   'rating': '4.2',
#   'oprice': '₹1,970'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Sonata',
#   'title': "Super Fibre Digital Grey Dial Men's Watch-NL87012PP03/NP87012PP03  ",
#   'price': '585',
#   'rating': '4.1',
#   'oprice': '₹585'},
#  {'brand': 'TIMEX',
#   'title': "Classics Analog Silver Dial Men's Watch-G910  ",
#   'price': '1,449',
#   'rating': '4.1',
#   'oprice': '₹1,449'},
#  {'brand': 'ALTURA',
#   'title': 'NOVA Skeleton Automatic Watch Mechanical Wrist Watch for Men Bezel Screw Design Silicone Band Self-Wind Business Watch for Men  ',
#   'price': '3,490',
#   'rating': '4.2',
#   'oprice': '₹3,490'},
#  {'brand': 'Titan',
#   'title': "Karishma Analog Multi-Colour Dial Men's Watch-NL1639SM01/NN1639SM01  ",
#   'price': '1,995',
#   'rating': '4.4',
#   'oprice': '₹1,995'},
#  {'brand': 'Brishti',
#   'title': "Brishti Super-Hero Multicolored Glowing Light Digital Wrist Watch for Kid's (Best Return Gift for Boy's)  ",
#   'price': '299',
#   'rating': '3.9',
#   'oprice': '₹299'},
#  {'brand': 'ZOVUTA',
#   'title': 'Stylish and Fashionable Waterproof LED Square Dial Watch for Boys and Girls  ',
#   'price': '289',
#   'rating': '4.2',
#   'oprice': '₹289'},
#  {'brand': 'TIMEX',
#   'title': "Analog Men's Watch  ",
#   'price': '849',
#   'rating': '4.1',
#   'oprice': '₹849'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Titan',
#   'title': "Ladies Neo-Ii Analog Blue Dial Women's Watch-NL2481SL08  ",
#   'price': '1,994',
#   'rating': '4.4',
#   'oprice': '₹1,994'},
#  {'brand': 'TIMEX',
#   'title': 'TW000Q809  ',
#   'price': '2,049',
#   'rating': '4.1',
#   'oprice': '₹2,049'},
#  {'brand': 'Titan',
#   'title': "Analog Gold Dial Men's Watch-NL1715YM02  ",
#   'price': '1,995',
#   'rating': '4.3',
#   'oprice': '₹1,995'},
#  {'brand': 'Armani Exchange',
#   'title': "Chronograph Men's Watch (Black Dial)  ",
#   'price': '12,995',
#   'rating': '4.3',
#   'oprice': '₹12,995'},
#  {'brand': 'ALPHABITA',
#   'title': "ALPHABITA Glorious Women's Rose Gold Smart Watch Talk 2 Bluetooth Calling Smartwatch with 3 Button, Hands On Voice Assistance HD Display, 14 Sports Modes with Puple Belt (Rose Gold)  ",
#   'price': '4,999',
#   'rating': '5.0',
#   'oprice': '₹4,999'},
#  {'brand': 'Acnos',
#   'title': 'Black dial-case and Black Leather Watch for Men Pack of - 1  ',
#   'price': '245',
#   'rating': '3.4',
#   'oprice': '₹245'},
#  {'brand': 'REDUX',
#   'title': "Analog Boy's & Men's Watch (Blue Dial Blue Colored Strap)  ",
#   'price': '266',
#   'rating': '3.6',
#   'oprice': '₹266'},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9138-SB NF9138 Analog-Digital Watch - for Men  ',
#   'price': '2,352',
#   'rating': '4.0',
#   'oprice': '₹2,352'},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9190-SILVER NF9190 Analog-Digital Watch - for Men  ',
#   'price': '2,552',
#   'rating': '2.7',
#   'oprice': '₹2,552'},
#  {'brand': 'NAVIFORCE',
#   'title': '9190  ',
#   'price': '2,552',
#   'rating': '5.0',
#   'oprice': '₹2,552'},
#  {'brand': 'Titan',
#   'title': 'Talk S with 1.78" AMOLED Display|Advanced BT Calling|Music Storage with Wireless Audio Connect|100+ Sports Modes|Animated Watchfaces|5 Days Battery|IP68 Water Resistant|Stress & Mood Monitor  ',
#   'price': '8,995',
#   'rating': '4.1',
#   'oprice': '₹8,995'},
#  {'brand': 'Shocknshop',
#   'title': 'Analogue Unisex Couple Combo Watch for Men & Women (Brown Dial & Colored Strap) -W246-236BR  ',
#   'price': '419',
#   'rating': '3.8',
#   'oprice': '₹419'},
#  {'brand': 'VILLS LAURRENS',
#   'title': "VL-1187 SLV Silver Dial Day & Date Series Analog Men's Watch  ",
#   'price': '359',
#   'rating': '5.0',
#   'oprice': '₹359'},
#  {'brand': 'Maicrogear',
#   'title': "Luxury Chronograph Watch for Men's  ",
#   'price': '2,999',
#   'rating': 'New to Amazon',
#   'oprice': '₹2,999'},
#  {'brand': 'VILLS LAURRENS',
#   'title': 'HMT-DLX BLK Quartz Original Gold Plated Day & Date Functioning Watch for Boys Analog Watch - for Men  ',
#   'price': '349',
#   'rating': '3.2',
#   'oprice': '₹349'},
#  {'brand': 'Fossil',
#   'title': "Grant Chronograph Black Dial Men's Watch-FS4832  ",
#   'price': '8,115',
#   'rating': '4.2',
#   'oprice': '₹8,115'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': '\n                                                    watch for boys\n                                                ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': '1,999.',
#   'rating': None,
#   'oprice': '₹1,999.00'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Sylvi',
#   'title': "Vogue Style Brown Leather Strap Analog Digital Men's Sports Wrist Watch  ",
#   'price': '990',
#   'rating': '3.9',
#   'oprice': '₹990'},
#  {'brand': 'Fossil',
#   'title': "Chronograph White Dial Men's Watch-CH2882  ",
#   'price': '4,935',
#   'rating': '4.3',
#   'oprice': '₹4,935'},
#  {'brand': 'Fossil',
#   'title': "Chronograph Men's Watch (Black Dial Black Colored Strap)  ",
#   'price': '6,597',
#   'rating': '4.1',
#   'oprice': '₹6,597'},
#  {'brand': 'Fossil',
#   'title': "Grant Chronograph Black Dial Men's Watch-FS4832  ",
#   'price': '8,115',
#   'rating': '4.2',
#   'oprice': '₹8,115'},
#  {'brand': 'REDUX',
#   'title': "Analog Boy's & Men's Watch (Blue Dial Blue Colored Strap)  ",
#   'price': '266',
#   'rating': '3.6',
#   'oprice': '₹266'},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9138-SB NF9138 Analog-Digital Watch - for Men  ',
#   'price': '2,352',
#   'rating': '4.0',
#   'oprice': '₹2,352'},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9190-SILVER NF9190 Analog-Digital Watch - for Men  ',
#   'price': '2,552',
#   'rating': '2.7',
#   'oprice': '₹2,552'},
#  {'brand': 'REDUX',
#   'title': "Analog Boy's & Men's Watch (Brown Dial Colored Strap)  ",
#   'price': '267',
#   'rating': '3.4',
#   'oprice': '₹267'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'VILLS LAURRENS',
#   'title': '0024 Gold Dial Metallic Chain Analog Watch for Men and Boys  ',
#   'price': '389',
#   'rating': '5.0',
#   'oprice': '₹389'},
#  {'brand': 'SHASHIKIRAN',
#   'title': "Boy's Glowing Light Digital Watch with Music on Theme of Spiderman and Ironman (Multicolor, Combo of 2)  ",
#   'price': '649',
#   'rating': '4.0',
#   'oprice': '₹649'},
#  {'brand': 'Maicrogear',
#   'title': "Luxury Chronograph Watch for Men's  ",
#   'price': '2,999',
#   'rating': 'M.R.P: ',
#   'oprice': '₹2,999'},
#  {'brand': 'REDUX',
#   'title': "Analog Blue-Grey Dial Men's Watch  ",
#   'price': '245',
#   'rating': '3.6',
#   'oprice': '₹245'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': '\n                                                    watch for boys\n                                                ',
#   'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': '1,999.',
#   'rating': None,
#   'oprice': '₹1,999.00'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Sylvi',
#   'title': "Vogue Style Brown Leather Strap Analog Digital Men's Sports Wrist Watch  ",
#   'price': '990',
#   'rating': '3.9',
#   'oprice': '₹990'},
#  {'brand': 'casera',
#   'title': 'Mahadev Dial And Mahadev Bracelet And Watch Combo Set For Boy And Men  ',
#   'price': '259',
#   'rating': '3.9',
#   'oprice': '₹259'},
#  {'brand': 'HAVELOCK',
#   'title': "Analog Men's Watch (Brown Dial Brown Colored Strap)  ",
#   'price': '399',
#   'rating': '3.7',
#   'oprice': '₹399'},
#  {'brand': 'Fossil',
#   'title': "Chronograph White Dial Men's Watch-CH2882  ",
#   'price': '4,935',
#   'rating': '4.3',
#   'oprice': '₹4,935'},
#  {'brand': 'REDUX',
#   'title': "Analog Boy's & Men's Watch (Blue Dial Blue Colored Strap)  ",
#   'price': '266',
#   'rating': '3.6',
#   'oprice': '₹266'},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9190-SILVER NF9190 Analog-Digital Watch - for Men  ',
#   'price': '2,552',
#   'rating': '2.7',
#   'oprice': '₹2,552'},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9138-SB NF9138 Analog-Digital Watch - for Men  ',
#   'price': '2,352',
#   'rating': '4.0',
#   'oprice': '₹2,352'},
#  {'brand': 'NAVIFORCE',
#   'title': '9190  ',
#   'price': '2,552',
#   'rating': '5.0',
#   'oprice': '₹2,552'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Fossil',
#   'title': "Chronograph Men's Watch (Black Dial Black Colored Strap)  ",
#   'price': '6,597',
#   'rating': '4.1',
#   'oprice': '₹6,597'},
#  {'brand': 'VILLS LAURRENS',
#   'title': '0024 Gold Dial Metallic Chain Analog Watch for Men and Boys  ',
#   'price': '389',
#   'rating': '5.0',
#   'oprice': '₹389'},
#  {'brand': 'Fossil',
#   'title': "Grant Chronograph Black Dial Men's Watch-FS4832  ",
#   'price': '8,115',
#   'rating': '4.2',
#   'oprice': '₹8,115'},
#  {'brand': 'SHASHIKIRAN',
#   'title': "Boy's Glowing Light Digital Watch with Music on Theme of Spiderman and Ironman (Multicolor, Combo of 2)  ",
#   'price': '649',
#   'rating': '4.0',
#   'oprice': '₹649'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': '\n                                                    watch for boys\n                                                ',
#   'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': '1,999.',
#   'rating': None,
#   'oprice': '₹1,999.00'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Sylvi',
#   'title': "Vogue Style Brown Leather Strap Analog Digital Men's Sports Wrist Watch  ",
#   'price': '990',
#   'rating': '3.9',
#   'oprice': '₹990'},
#  {'brand': 'Fossil',
#   'title': "Chronograph White Dial Men's Watch-CH2882  ",
#   'price': '4,935',
#   'rating': '4.3',
#   'oprice': '₹4,935'},
#  {'brand': 'HAVELOCK',
#   'title': "Analog Men's Watch (Brown Dial Brown Colored Strap)  ",
#   'price': '399',
#   'rating': '3.7',
#   'oprice': '₹399'},
#  {'brand': 'Fossil',
#   'title': "Grant Chronograph Black Dial Men's Watch-FS4832  ",
#   'price': '8,115',
#   'rating': '4.2',
#   'oprice': '₹8,115'},
#  {'brand': 'REDUX',
#   'title': "Analog Boy's & Men's Watch (Blue Dial Blue Colored Strap)  ",
#   'price': '266',
#   'rating': '3.6',
#   'oprice': '₹266'},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9190-SILVER NF9190 Analog-Digital Watch - for Men  ',
#   'price': '2,552',
#   'rating': '2.7',
#   'oprice': '₹2,552'},
#  {'brand': 'NAVIFORCE',
#   'title': '9190  ',
#   'price': '2,552',
#   'rating': '5.0',
#   'oprice': '₹2,552'},
#  {'brand': 'NAVIFORCE',
#   'title': 'NF9138-SB NF9138 Analog-Digital Watch - for Men  ',
#   'price': '2,352',
#   'rating': '4.0',
#   'oprice': '₹2,352'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Fossil',
#   'title': "Chronograph Men's Watch (Black Dial Black Colored Strap)  ",
#   'price': '6,597',
#   'rating': '4.1',
#   'oprice': '₹6,597'},
#  {'brand': 'VILLS LAURRENS',
#   'title': '0024 Gold Dial Metallic Chain Analog Watch for Men and Boys  ',
#   'price': '389',
#   'rating': '5.0',
#   'oprice': '₹389'},
#  {'brand': 'VILLS LAURRENS',
#   'title': "VL-1187 SLV Silver Dial Day & Date Series Analog Men's Watch  ",
#   'price': '359',
#   'rating': '5.0',
#   'oprice': '₹359'},
#  {'brand': 'SHASHIKIRAN',
#   'title': "Boy's Glowing Light Digital Watch with Music on Theme of Spiderman and Ironman (Multicolor, Combo of 2)  ",
#   'price': '649',
#   'rating': '4.0',
#   'oprice': '₹649'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': '\n                                                    watch for boys\n                                                ',
#   'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None}]

# %%
import pandas as pd
pd.DataFrame(all_data).dropna(how='any').to_excel('amazon.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Data Science DiGI\amazon_scraper.ipynb Cell 4 in 2
#       <a href='vscode-notebook-cell:/d%3A/Data%20Science%20DiGI/amazon_scraper.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20Science%20DiGI/amazon_scraper.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> pd.DataFrame(all_data).dropna(how='any').to_excel('amazon.xlsx', index=False)
#
# NameError: name 'all_data' is not defined
