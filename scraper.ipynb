# %%
from dputils.scrape import Scraper,Tag

# %%
url='https://www.flipkart.com/search?q=bags&page=10'
sc=Scraper(url)

# %%
target = Tag('div', cls = '_1YokD2 _3Mn1Gg') # important
items = Tag('div', cls = '_1xHGtK _373qXS') # important repeating item
brand = Tag('div', cls = '_2WkVRV')
details = Tag('a', cls='IRpwTa')
price = Tag('div', cls='_30jeq3')
color = Tag('div', cls='_3eWWd-')
discount = Tag('div', cls='_3Ay6Sb')

# %%
data = sc.get_all(
        target, items, brand=brand,
        details=details, price=price,
        color=color, discount=discount
)
print(len(data))
# Out:
# 40

# %%
data
# Out:
# [{'brand': 'WROGN',
#   'details': 'Large 40 L Laptop Backpack Spacy Freeride Unisex Bag wi...',
#   'price': '₹730',
#   'color': 'Multicolor',
#   'discount': '85% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Large 36 L Backpack DRIP PRO 03 GREEN BACKPACK 36 L',
#   'price': '₹1,839',
#   'color': 'Green',
#   'discount': '36% off'},
#  {'brand': 'HP',
#   'details': 'Medium 30 L Backpack laptop Bag||College Bag||BACKPACK|...',
#   'price': '₹404',
#   'color': 'Black',
#   'discount': '63% off'},
#  {'brand': 'GOOD FRIENDS',
#   'details': 'Medium 21 L Backpack Design Premium Polyester Waterproo...',
#   'price': '₹355',
#   'color': 'Grey',
#   'discount': '74% off'},
#  {'brand': 'NASHER MILES',
#   'details': 'Small 15 L Backpack CSK Yellow Drawstring Cricket Daypa...',
#   'price': '₹291',
#   'color': 'Yellow',
#   'discount': '80% off'},
#  {'brand': 'WROGN',
#   'details': 'Large 35 L Laptop Backpack Axe Bone backpack spacy unis...',
#   'price': '₹495',
#   'color': 'Multicolor, Yellow',
#   'discount': '83% off'},
#  {'brand': 'REEBOK',
#   'details': 'Large 33 L Backpack Tech Style Bp M',
#   'price': '₹2,739',
#   'color': 'Grey',
#   'discount': '21% off'},
#  {'brand': 'aob',
#   'details': 'Large 70 L Backpack UNISEX WaterProof Mountain Rucksack...',
#   'price': '₹599',
#   'color': 'Grey',
#   'discount': '80% off'},
#  {'brand': 'Gear',
#   'details': 'Medium 25 L Backpack BOMBER ECO STATEMENT 2C',
#   'price': '₹489',
#   'color': 'Red, Black',
#   'discount': '75% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Medium 25 L Laptop Backpack CHESTER PRO 02 LAPTOP BACKP...',
#   'price': '₹2,039',
#   'color': 'Blue',
#   'discount': '46% off'},
#  {'brand': 'Isparro',
#   'details': 'Large 37 L Laptop Backpack Laptop Backpack navy blue ca...',
#   'price': '₹1,949',
#   'color': 'Blue',
#   'discount': '2% off'},
#  {'brand': 'LAYONEX',
#   'details': 'Medium 25 L Laptop Backpack Laptop Bag/ Laptop Backpack...',
#   'price': '₹441',
#   'color': 'Blue',
#   'discount': '70% off'},
#  {'brand': 'REEBOK',
#   'details': 'Medium 22 L Laptop Backpack Bags',
#   'price': '₹586',
#   'color': 'Grey',
#   'discount': '54% off'},
#  {'brand': 'F GEAR',
#   'details': 'Medium 26 L Backpack Burner P8',
#   'price': '₹799',
#   'color': 'Multicolor',
#   'discount': '52% off'},
#  {'brand': 'WROGN',
#   'details': 'Large 35 L Laptop Backpack HARDROCK Unisex Backpack wit...',
#   'price': '₹838',
#   'color': 'Tan',
#   'discount': '76% off'},
#  {'brand': 'TANAUM',
#   'details': 'Medium 22 L Backpack Stylish & unisex college bag tuiti...',
#   'price': '₹297',
#   'color': 'Black, Grey',
#   'discount': '82% off'},
#  {'brand': 'NASHER MILES',
#   'details': 'Large 40 L Laptop Backpack Corporate Black Laptop Backp...',
#   'price': '₹1,349',
#   'color': 'Black',
#   'discount': '77% off'},
#  {'brand': 'ARISTOCRAT',
#   'details': 'Medium 28 L Backpack DRIFT BACKPACK (E) TEAL',
#   'price': '₹1,049',
#   'color': 'Blue',
#   'discount': '59% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Medium 27 L Backpack BEATLE3 BACKPACK (E) GREY-RED',
#   'price': '₹839',
#   'color': 'Green',
#   'discount': '58% off'},
#  {'brand': 'TRAVEL POINT',
#   'details': 'Medium 25 L Laptop Backpack for Office/College/School/T...',
#   'price': '₹499',
#   'color': 'Black, White',
#   'discount': '83% off'},
#  {'brand': 'STATUS',
#   'details': 'Large 45 L Laptop Backpack Large 45 L Laptop Trendy Lap...',
#   'price': '₹539',
#   'color': 'Red',
#   'discount': '79% off'},
#  {'brand': 'Lunar',
#   'details': 'Large 35 L Backpack Comet 4',
#   'price': '₹799',
#   'color': 'Blue, Black',
#   'discount': '52% off'},
#  {'brand': 'WROGN',
#   'details': 'Large 35 L Laptop Backpack HARDROCK Unisex Backpack wit...',
#   'price': '₹838',
#   'color': 'Tan',
#   'discount': '76% off'},
#  {'brand': 'TANAUM',
#   'details': 'Large 50 L Backpack Traking Travel Bags',
#   'price': '₹439',
#   'color': 'Blue',
#   'discount': '70% off'},
#  {'brand': 'SAFARI',
#   'details': 'Large 35 L Backpack HiTech 35 Ltrs Water Resistant Back...',
#   'price': '₹1,649',
#   'color': 'Black',
#   'discount': '31% off'},
#  {'brand': 'Ficro',
#   'details': 'Large 35 L Laptop Backpack Backpack Water Resistant Sli...',
#   'price': '₹646',
#   'color': 'Blue',
#   'discount': '65% off'},
#  {'brand': 'NSUN QUECHUA',
#   'details': 'Small 10 L Backpack Bag',
#   'price': '₹548',
#   'color': 'Green',
#   'discount': '65% off'},
#  {'brand': 'Safwan',
#   'details': 'Medium 25 L Backpack UNISEX',
#   'price': '₹359',
#   'color': 'Blue',
#   'discount': '70% off'},
#  {'brand': 'SKYBAGS',
#   'details': '21.43 L Backpack RAGER 08',
#   'price': '₹799',
#   'color': 'Black',
#   'discount': '57% off'},
#  {'brand': 'familiar',
#   'details': 'Large 60 L Backpack Expandable Travel Rucksack for Outd...',
#   'price': '₹519',
#   'color': 'Blue',
#   'discount': '82% off'},
#  {'brand': 'SANCHIFY',
#   'details': 'Small 20 L Backpack Faux Leather Backpack College Tuiti...',
#   'price': '₹500',
#   'color': 'Brown',
#   'discount': '74% off'},
#  {'brand': 'World Speed',
#   'details': 'Small 10 L Backpack Tuition Bags Backpack',
#   'price': '₹359',
#   'color': 'Blue',
#   'discount': '78% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Medium 28 L Backpack Polyester 28L Drip Plus 04 Backpac...',
#   'price': '₹1,895',
#   'color': 'Blue',
#   'discount': '24% off'},
#  {'brand': 'Safari',
#   'details': '23.5 L Backpack QUINT 19 CB COSMIC BLUE',
#   'price': '₹961',
#   'color': 'Blue',
#   'discount': '56% off'},
#  {'brand': 'WROGN',
#   'details': 'Large 35 L Laptop Backpack Axe 4D backpack spacy unisex...',
#   'price': '₹495',
#   'color': 'Multicolor',
#   'discount': '83% off'},
#  {'brand': 'WROGN',
#   'details': 'Large 45 L Laptop Backpack Laptop backpack spacy unisex...',
#   'price': '₹689',
#   'color': 'Blue',
#   'discount': '82% off'},
#  {'brand': 'Wildcraft',
#   'details': 'Medium 23 L Backpack Stanza',
#   'price': '₹1,159',
#   'color': 'Black',
#   'discount': '51% off'},
#  {'brand': 'PUMA',
#   'details': '18.5 L Backpack 7566301',
#   'price': '₹1,449',
#   'color': 'Black',
#   'discount': '3% off'},
#  {'brand': 'Safari',
#   'details': 'Large 38 L Backpack CLAN',
#   'price': '₹1,517',
#   'color': 'Black',
#   'discount': '55% off'},
#  {'brand': 'ARISTOCRAT',
#   'details': 'Medium 26 L Backpack COSMIC BACKPACK (E) TEAL',
#   'price': '₹759',
#   'color': 'Blue',
#   'discount': '66% off'}]
